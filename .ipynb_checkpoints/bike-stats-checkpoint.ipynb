# %% [markdown]
# # Bike Stats Notebook. Data Analysis. Madeline Peters.

# %%
# Global imports
import pandas as pd
import numpy as np
import datetime as dt

# %%
df_weather = pd.read_csv('./weather.csv')

# %%
df_trip = pd.read_csv('./trip.csv', error_bad_lines=False)
# Out:
# b'Skipping line 50794: expected 12 fields, saw 20\n'

# %%
df_station = pd.read_csv('./station.csv')

# %% [markdown]
# ### What is the average trip duration for a borrowed bicycle?

# %%
df_trip.head(2)
# Out:
#    trip_id         starttime          stoptime    bikeid  tripduration  \
# 0      431  10/13/2014 10:31  10/13/2014 10:48  SEA00298       985.935
# 1      432  10/13/2014 10:32  10/13/2014 10:48  SEA00195       926.375
#
#      from_station_name                                    to_station_name  \
# 0  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 1  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
#
#   from_station_id to_station_id usertype gender  birthyear
# 0          CBD-06         PS-04   Member   Male     1960.0
# 1          CBD-06         PS-04   Member   Male     1970.0

# %%
df_trip.tripduration.mean() // 60
# Out:
# 19.638261255666293

# %% [markdown]
# ### What’s the most common age of a bicycle-sharer?

# %%
grouped = df_trip.birthyear.groupby(df_trip.birthyear)

# %%
series = grouped.count().sort_values(ascending=False)
series
# Out:
# birthyear
# 1987.0    18128
# 1985.0    10665
# 1981.0     9953
# 1982.0     9429
# 1984.0     9113
# 1988.0     8633
# 1986.0     8096
# 1983.0     7832
# 1990.0     7529
# 1989.0     6581
# 1991.0     5696
# 1980.0     5113
# 1977.0     4640
# 1992.0     4415
# 1978.0     4218
# 1975.0     3912
# 1979.0     3654
# 1972.0     3496
# 1962.0     3387
# 1971.0     3260
# 1976.0     3193
# 1974.0     3172
# 1965.0     2704
# 1993.0     2635
# 1967.0     2600
# 1964.0     2565
# 1968.0     2519
# 1970.0     2463
# 1969.0     2447
# 1966.0     2139
#           ...
# 1961.0     1793
# 1963.0     1643
# 1959.0     1476
# 1950.0     1210
# 1994.0      955
# 1956.0      919
# 1995.0      910
# 1960.0      878
# 1947.0      769
# 1955.0      748
# 1953.0      678
# 1951.0      592
# 1957.0      474
# 1952.0      403
# 1958.0      365
# 1996.0      355
# 1949.0      338
# 1954.0      295
# 1945.0      197
# 1946.0      139
# 1997.0      101
# 1948.0       65
# 1939.0       40
# 1998.0       36
# ...

# %%
2018 - 1987
# Out:
# 31

# %% [markdown]
# ### Given all the weather data here, find the average precipitation per month, and the median precipitation.

# %%
df_weather.head
# Out:
# <bound method NDFrame.head of            Date  Max_Temperature_F  Mean_Temperature_F  Min_TemperatureF  \
# 0    10/13/2014                 71                62.0                54
# 1    10/14/2014                 63                59.0                55
# 2    10/15/2014                 62                58.0                54
# 3    10/16/2014                 71                61.0                52
# 4    10/17/2014                 64                60.0                57
# 5    10/18/2014                 68                64.0                59
# 6    10/19/2014                 73                64.0                55
# 7    10/20/2014                 66                60.0                55
# 8    10/21/2014                 64                58.0                55
# 9    10/22/2014                 60                58.0                57
# 10   10/23/2014                 62                55.0                50
# ...

# %%
df_weather.Date = pd.to_datetime(df_weather.Date)

# %%
df_weather['DAY'] = df_weather.Date.apply(dt.datetime.isoweekday)
df_weather['DAY_OF_WEEK'] = df_weather.Date.dt.weekday_name
df_weather['MONTH'] = df_weather.Date.dt.month
df_weather['YEAR'] = df_weather.Date.dt.year

# %%
df_weather.head
# Out:
# <bound method NDFrame.head of           Date  Max_Temperature_F  Mean_Temperature_F  Min_TemperatureF  \
# 0   2014-10-13                 71                62.0                54
# 1   2014-10-14                 63                59.0                55
# 2   2014-10-15                 62                58.0                54
# 3   2014-10-16                 71                61.0                52
# 4   2014-10-17                 64                60.0                57
# 5   2014-10-18                 68                64.0                59
# 6   2014-10-19                 73                64.0                55
# 7   2014-10-20                 66                60.0                55
# 8   2014-10-21                 64                58.0                55
# 9   2014-10-22                 60                58.0                57
# 10  2014-10-23                 62                55.0                50
# 11  2014-10-24                 60                56.0                51
# ...

# %%
grouped = df_weather.Precipitation_In.groupby(df_weather.MONTH)

# %%
series = grouped.count()
series
# Out:
# MONTH
# 1     62
# 2     57
# 3     62
# 4     60
# 5     62
# 6     60
# 7     62
# 8     62
# 9     30
# 10    50
# 11    60
# 12    62
# Name: Precipitation_In, dtype: int64

# %%
df_weather['Precipitation_In'].median()
# Out:
# 0.0

# %% [markdown]
# ### What’s the average number of bikes at a given bike station?

# %%
df_station.head
# Out:
# <bound method NDFrame.head of    station_id                                               name        lat  \
# 0       BT-01                                 3rd Ave & Broad St  47.618418
# 1       BT-03                                  2nd Ave & Vine St  47.615829
# 2       BT-04                             6th Ave & Blanchard St  47.616094
# 3       BT-05                             2nd Ave & Blanchard St  47.613110
# 4      CBD-03                                 7th Ave & Union St  47.610731
# 5      CBD-04                                 Union St & 4th Ave  47.609221
# 6      CBD-05                                1st Ave & Marion St  47.604058
# 7      CBD-06                                2nd Ave & Spring St  47.605950
# 8      CBD-07                     City Hall / 4th Ave & James St  47.603509
# 9      CBD-13                                  2nd Ave & Pine St  47.610185
# 10      CD-01                            12th Ave & E Yesler Way  47.602103
# ...

# %%
df_station['current_dockcount'].mean()
# Out:
# 16.517241379310345

# %% [markdown]
# ### When a bike station is modified, is it more likely that it’ll lose bikes or gain bikes? How do you know?

# %% [markdown]
# ##### I would solve this problem by looking at the stations that have a modification_date and by checking their current_dockcount versus their install_dockcount

# %% [markdown]
# ### Come up with 3 more questions that can be answered with this data set.

# %% [markdown]
# ##### What is the total miles traveled?

# %%
df_trip.tripduration.sum()
# Out:
# 338002362.54099995

# %% [markdown]
# ##### What age is the oldest biker?

# %%
2018 - 1931
# Out:
# 87

# %% [markdown]
# ##### What is the average temperature?

# %%
df_weather.Max_Temperature_F.mean()
# Out:
# 64.02757619738752
